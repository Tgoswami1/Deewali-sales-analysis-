# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data = pd.read_csv("Diwali Sales Data.csv", encoding= 'unicode_escape')

# %%
data
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
data.isnull().sum()
# Out:
# User_ID                 0
# Cust_name               0
# Product_ID              0
# Gender                  0
# Age Group               0
# Age                     0
# Marital_Status          0
# State                   0
# Zone                    0
# Occupation              0
# Product_Category        0
# Orders                  0
# Amount                 12
# Status              11251
# unnamed1            11251
# dtype: int64

# %%
data.shape
# Out:
# (11251, 15)

# %%
# dropping blank columns.
#data.drop(['Status', 'unnamed1'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount', 'Status', 'unnamed1'],
#       dtype='object')

# %%
data.describe()
# Out:
#             User_ID           Age  Marital_Status        Orders        Amount  \
# count  1.125100e+04  11251.000000    11251.000000  11251.000000  11239.000000
# mean   1.003004e+06     35.421207        0.420318      2.489290   9453.610858
# std    1.716125e+03     12.754122        0.493632      1.115047   5222.355869
# min    1.000001e+06     12.000000        0.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000        0.000000      1.500000   5443.000000
# 50%    1.003065e+06     33.000000        0.000000      2.000000   8109.000000
# 75%    1.004430e+06     43.000000        1.000000      3.000000  12675.000000
# max    1.006040e+06     92.000000        1.000000      4.000000  23952.000000
#
#        Status  unnamed1
# count     0.0       0.0
# mean      NaN       NaN
# std       NaN       NaN
# min       NaN       NaN
# 25%       NaN       NaN
# 50%       NaN       NaN
# 75%       NaN       NaN
# max       NaN       NaN

# %%
#use describe for specific columns
data[['Age', 'Amount', 'Orders']].describe()
# Out:
#                 Age        Amount        Orders
# count  11251.000000  11239.000000  11251.000000
# mean      35.421207   9453.610858      2.489290
# std       12.754122   5222.355869      1.115047
# min       12.000000    188.000000      1.000000
# 25%       27.000000   5443.000000      1.500000
# 50%       33.000000   8109.000000      2.000000
# 75%       43.000000  12675.000000      3.000000
# max       92.000000  23952.000000      4.000000

# %% [markdown]
# # Exploratory data analysis

# %% [markdown]
# # Gender

# %%
# plotting bar chart for gender and its count

ax = sns.countplot(x ='Gender', data = data)

for bars in ax.containers:
    ax.bar_label(bars)

# %% [markdown]
# from above graph we can see the most of the buyers are females and even the purchasing power of females is greater than mens.

# %% [markdown]
# # Age

# %%
ax = sns.countplot(x ='Age Group', hue = 'Gender', data=data)

for bars in ax.containers:
    ax.bar_label(bars)

# %%
# Total Amount vs Age Group
sales_age = data.groupby(['Age Group'],as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)
# Out:
# <AxesSubplot: xlabel='Age Group', ylabel='Amount'>

# %% [markdown]
# from the above graphs we can see that the most of the buyers are of age group 26-35 and most of them are females.

# %% [markdown]
# # State

# %%
#total number of orders from top 1op 10 states
sales_state = data.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,15)})
sns.barplot(data = sales_state, x = 'State',y= 'Orders')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Orders'>

# %%
#total amount/sales from top 10states

sales_state = data.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by= 'Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(15,15)})
sns.barplot(data = sales_state, x = 'State', y = 'Amount')
# Out:
# <AxesSubplot: xlabel='State', ylabel='Amount'>

# %% [markdown]
# We can see from the above graphs most of the orders are from Uttar Pradesh, Maharashtra, Karnatka respectively.

# %% [markdown]
# # Marital Status

# %%
ax = sns.countplot(data = data, x = 'Marital_Status')

sns.set(rc={'figure.figsize':(8,8)})
for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = data.groupby(['Marital_Status', 'Gender'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(6,5)})
sns.barplot(data = sales_state, x = 'Marital_Status',y= 'Amount', hue='Gender')
# Out:
# <AxesSubplot: xlabel='Marital_Status', ylabel='Amount'>

# %% [markdown]
# # Occupation

# %%
sns.set(rc={'figure.figsize':(20,10)})

ax = sns.countplot(data = data, x='Occupation')

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = data.groupby(['Occupation'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Occupation',y= 'Amount')
# Out:
# <AxesSubplot: xlabel='Occupation', ylabel='Amount'>

# %% [markdown]
# From the above graphs we can see the most of the buyers are working in IT, Aviation and Healthcare sectors.

# %% [markdown]
# # Product Category

# %%
ax = sns.countplot(data = data, x= 'Product_Category')

sns.set(rc={'figure.figsize':(20,10)})

for bars in ax.containers:
    ax.bar_label(bars)

# %%
sales_state = data.groupby(['Product_Category'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,10)})
sns.barplot(data = sales_state, x = 'Product_Category',y= 'Amount')
# Out:
# <AxesSubplot: xlabel='Product_Category', ylabel='Amount'>

# %% [markdown]
# From the above graph we can see that the most of the products sold from Food, Clothing & Electronics category.

# %%
# Top 10 most sold products
sales_state = data.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
# Out:
# <AxesSubplot: xlabel='Product_ID', ylabel='Orders'>

# %% [markdown]
# # Conclusion

# %% [markdown]
# * The most of the Sales comes from the Married womens age group of 26-35yrs from the state UP, Maharashtra and Karnatka
# * Working in IT, Aviation & Healthcare sectors and more like to buy products from Food, Clothing and Electronic categories.
